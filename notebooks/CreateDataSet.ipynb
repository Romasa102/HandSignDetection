# %% [markdown]
# # Import Library

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))


from src.utils import *
from src import config

import cv2
import numpy as np
import matplotlib.pyplot as plt
import time
import mediapipe as mp
# Out:
# 2026-03-08 00:23:21.136061: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-08 00:23:21.158556: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-03-08 00:23:21.158582: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-03-08 00:23:21.159372: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-03-08 00:23:21.163364: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
DATA_PATH = os.path.join('../datasets',config.DATAFILE_NAME)

# %% [markdown]
# # Create the directory for the datasets
#
# This code would create the folder which would look like following.
# ```
# NAME_OF_DATAFILE
# |
# |--ACTION1
# |   |--1
# |   |--2
# |   |--3
# |   |--NO_SEQUENCES
# |
# |--ACTION2
#     |--1
#     |--2
#     |--3
#     |--NO_SEQUENCES
# ```

# %%
for action in config.ACTIONS:
    for sequence in range(config.NO_SEQUENCES):
        try:
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # Data Collection

# %% [markdown]
# > [!WARNING]
# Do not run this code when there is existing data inside the DATAFILE_NAME

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as model:
    for action in config.ACTIONS:
        for sequence in range(config.NO_SEQUENCES):
            for frame_num in range(config.SEQUENCE_LENGTH):
                ret, frame = cap.read()
                image, results = media_pipe_detection(frame, model)
                draw_landmarks(frame, results)

                if frame_num == 0:
                    cv2.putText(frame, 'STARTING COLLECTION', (120,200),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(frame, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 1, cv2.LINE_AA)
                    cv2.imshow('Detection', frame)
                    cv2.waitKey(2000)
                else:
                    cv2.putText(frame, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 1, cv2.LINE_AA)
                    cv2.imshow('Detection', frame)

                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765798678.670266 6625132 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 90.5), renderer: Apple M1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1765798678.854541 6625799 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1765798678.881684 6625804 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1765798678.886941 6625802 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1765798678.890191 6625804 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ...
